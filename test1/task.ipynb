# %% [markdown]
# # Контрольная работа
#
# Нужно написать программу, которая парсит сайт и складывает результат в базу данных. Нужно уместно использовать классы, написать к программе тесты (полное покрытие не требуется). И залить все в репозиторий через гит.
#
# ## Критерии оценки
#
# **На 5**
# - работает хоть что-то, оно залито через гит
# - используются классы
#
# **На 6**
# - вся нужная информация с сайта парсится
# - залито через гит
# - используются классы
#
# **На 7**
# - вся нужная информация с сайта парсится
# - залито через гит
# - используются классы
# - значения кладутся в базу данных
#
# **На 8**
# - вся нужная информация с сайта парсится
# - залито через гит
# - используются классы
# - значения кладутся в базу данных, в ней больше одной таблицы
#
# **На 9**
# - вся нужная информация с сайта парсится
# - залито через гит
# - используются классы
# - значения кладутся в базу данных, в ней больше одной таблицы
# - есть тесты (возможно не полное покрытие, но они должны быть осмысленные), тесты проходятся
#
# **На 10**
# - вся нужная информация с сайта парсится
# - залито через гит
# - используются классы
# - значения кладутся в базу данных, в ней больше одной таблицы
# - есть тесты (возможно не полное покрытие, но они должны быть осмысленные), тесты проходятся
# - используются принципы чистого кода, типизация, код логичный, не мусорный, есть обработка ошибок
#
# Можно пользоваться всеми конспектами из репозитория и гуглить. На контрольную дается 1,5 часа.
#
# ## Сайт и что с него нужно спарсить
#
# https://www.restoran.ru
# Нужно спарсить все отзывы для ресторанов с определенной кухней
# Для каждого отзыва нужна дополнительная информация
# - Название ресторана
# - Все теги ресторана (кухня может быть Рыбной + Авторской + Французской)
# - Средний чек ресторана
# - Оценка ресторана по 5балльной шкале
#
# Подумайте о том, как хорошо организовать базу данных
#
# - Айзетов Павел - Азиатская
# - Ишеев Денис - Грузинская
# - Захаров Владимир - Европейская
# - ??? Миша - Русская
# - Чистяков Андрей - Французская

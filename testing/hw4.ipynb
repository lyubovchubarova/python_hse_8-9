# %% [markdown]
# ## Домашнее задание 4
# ### Дедлайн - 7 марта 23:59

# %% [markdown]
# Вам нужно написать программу, для имитации флеш-карточек для запоминания английских слов и юнит-тесты для нее. Постарайтесь использовать ```@parameterized.expand```
#
#
# Пример использования программы:
# ```
# >>> from flash_cards import FlashCards
# >>> fc = FlashCards()
# >>> fc.add_word('груша', 'pear')
# Добавлено слово 'груша'
# >>> fc.add_word('хурма', 'persimmon')
# Добавлено слово 'хурма'
# >>> fc.add_word('яблоко', 'apple')
# Добавлено слово 'яблоко'
# >>> fc.words
# ['яблоко', 'хурма', 'груша']
# >>> fc.add_word('груша', 'pear')
# Такое слово уже есть в словаре
# >>>> fc.play()
# яблоко
# apple
# хурма
# tomato
# груша
# Pear
# Готово! Правильно 2 из 3 слов
#
# >>> fc.delete_word('хурма')
# Удалено слово 'хурма'
# >>> fc.words
# ['яблоко', 'груша']
# >>> fc.delete_word('хурма')
# Такого слова нет в словаре
#
# >>> fc.add_word(123, 231)
# Неправильный тип ввода!
# >>> fc.delete_word(123)
# Неправильный тип ввода!
#
# >>> fc.delete_word('яблоко')
# Удалено слово 'яблоко'
# >>> fc.delete_word('груша')
# Удалено слово 'груша'
# >>> fc.words
# []
# >>>> fc.play()
# В словаре нет слов
# ```

# %% [markdown]
# Cтруктура класса:
#
# ```
# class FlashCards():
#     def __init__(self):
#         '''
#         Создаст все требующиеся атрибуты.
#         '''
#         pass
#
#     def play(self) -> str:
#         '''
#         Выдает русские слова из словаря в рандомном порядке,
#         сверяет введенный пользователем перевод с правильным
#         (регистр введенного слова при этом не важен),
#         пока слова в словаре не закончатся.
#         Возвращает строку с количеством правильных ответов/общим количеством
#         слов в словаре (см пример работы).
#         '''
#
#     def add_word(self, russian: str, english: str) -> str:
#         '''
#         Добавляет в словарь новую пару слов,
#         если русского слова еще нет в словаре.
#         Возвращает строку в зависимоти от результата (см пример работы).
#         '''
#
#     def delete_word(self, russian: str) -> str:
#         '''
#         Удаляет из словаря введенное русское слово
#         и соответсвующее ему английское.
#         Возвращает строку в зависимоти от результата (см пример работы).
#         '''
# ```
# Направление перевода только одно: с русского на английский, русские слова в словаре уникальны, английские - не обязательно.

# %% [markdown]
# Критерии на 10:
# - 100% или близкое к 100 покрытие кода тестами (все строки методов flash_cards покрыты тестами), проверять с помощью coverage
# - юнит-тесты проходятся
# - юнит-тесты не зависят друг от друга, нормально запускаются по отдельности
# - в коде и юнит-тестах учтены все варианты ввода/развития событий, указанные в примерах
# - в тестах проверяются побочные эффекты (например содержимое words)
#
# В папке с ДЗ нужно имитировать структуру проекта с тестами
